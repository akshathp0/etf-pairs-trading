# %%
# %load_ext autoreload
# %autoreload 2
# %reload_ext autoreload
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import os
os.chdir('..')
os.getcwd()
# Out:
# '/Users/ak/Documents/GitHub/rise-project/pair_trading'

# %%
import numpy as np, random, os
import pandas as pd
from models import random_forest

np.random.seed(42)
random.seed(42)
os.environ["PYTHONHASHSEED"] = "42"

etf_pairs = [('VO','IWB'), 
         ('VO','SPY'), 
         ('VO','SCHX'), 
         ('VO','SPLG'), 
         ('VO', 'IVV'),
         ('VO', 'VOO'), 
         ('DVY','IWR'), 
         ('SCHV', 'SPHQ'), 
         ('IWR','DIA'), 
         ('DVY','OEF'), 
         ('VTV', 'SPHQ'), 
         ('RSP', 'DIA'), 
         ('VO', 'DIA'), 
         ('DVY', 'FVD'), 
         ('DVY','VYM')] # closing

train_prices = pd.read_csv("etf_train_prices.csv", index_col = 0, parse_dates = True)
test_prices = pd.read_csv("etf_test_prices.csv", index_col = 0, parse_dates = True)

# %%
pair_models, pair_betas, feature_cols = random_forest.grid_search(etf_pairs, train_prices, test_prices)
# Out:
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   0.4s
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   0.5s
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   0.6s
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   0.7s
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   0.8s
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   0.9s
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   1.0s
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=   0.4s
# ...

# %%
random_forest.run_simulation(etf_pairs, test_prices, pair_models, feature_cols, pair_betas)
# Out:
# Summary
# VO_IWB: Final Value = $102.67, Total Return = 2.67%, Trades = 32
# VO_SPY: Final Value = $101.35, Total Return = 1.35%, Trades = 29
# VO_SCHX: Final Value = $100.51, Total Return = 0.51%, Trades = 30
# VO_SPLG: Final Value = $102.30, Total Return = 2.30%, Trades = 30
# VO_IVV: Final Value = $102.70, Total Return = 2.70%, Trades = 29
# VO_VOO: Final Value = $100.46, Total Return = 0.46%, Trades = 27
# DVY_IWR: Final Value = $98.92, Total Return = -1.08%, Trades = 15
# SCHV_SPHQ: Final Value = $100.70, Total Return = 0.70%, Trades = 25
# IWR_DIA: Final Value = $103.01, Total Return = 2.80%, Trades = 43
# DVY_OEF: Final Value = $106.91, Total Return = 6.91%, Trades = 33
# VTV_SPHQ: Final Value = $104.40, Total Return = 4.40%, Trades = 30
# RSP_DIA: Final Value = $101.49, Total Return = 1.46%, Trades = 28
# VO_DIA: Final Value = $101.50, Total Return = 1.50%, Trades = 33
# DVY_FVD: Final Value = $103.35, Total Return = 3.35%, Trades = 31
# ...
