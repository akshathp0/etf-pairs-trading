# %%
import yfinance as yf
import numpy as np
import pandas as pd

spy = yf.download("SPY", start = "2020-01-02", end = "2024-12-31")['Close']

returns = spy.pct_change().dropna()

sharpe = np.mean(returns) / np.std(returns) * np.sqrt(252)

sharpe
# Out:
# /var/folders/qd/xclxh05s0x9509nblm6z434w0000gp/T/ipykernel_39830/651211237.py:5: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   spy = yf.download("SPY", start = "2020-01-02", end = "2024-12-31")['Close']
# [*********************100%***********************]  1 of 1 completed
# /opt/anaconda3/envs/rise-project/lib/python3.12/site-packages/numpy/_core/fromnumeric.py:4062: FutureWarning: The behavior of DataFrame.std with axis=None is deprecated, in a future version this will reduce over both axes and return a scalar. To retain the old behavior, pass axis=0 (or do not pass axis)
#   return std(axis=axis, dtype=dtype, out=out, ddof=ddof, **kwargs)
# Ticker
# SPY    0.745329
# dtype: float64
