# %%
import pandas as pd
import numpy as np, random, os
from xgboost import XGBClassifier
from sklearn.model_selection import GridSearchCV, TimeSeriesSplit
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
from collections import Counter
import matplotlib.pyplot as plt
import seaborn as sns

np.random.seed(42)
random.seed(42)
os.environ["PYTHONHASHSEED"] = "42"

etf_pairs = [('VO','IWB'), 
         ('VO','SPY'), 
         ('VO','SCHX'), 
         ('VO','SPLG'), 
         ('VO', 'IVV'),
         ('VO', 'VOO'), 
         ('DVY','IWR'), 
         ('SCHV', 'SPHQ'), 
         ('IWR','DIA'), 
         ('DVY','OEF'), 
         ('VTV', 'SPHQ'), 
         ('RSP', 'DIA'), 
         ('VO', 'DIA'), 
         ('DVY', 'FVD'), 
         ('DVY','VYM')] # closing

train_prices = pd.read_csv("etf_train_prices.csv", index_col = 0, parse_dates = True)
test_prices = pd.read_csv("etf_test_prices.csv", index_col = 0, parse_dates = True)

def rolling_zscore(series, window = 60):
    mean = series.rolling(window).mean()
    std = series.rolling(window).std()
    return (series - mean) / std

def predict_mean_reversion_label(
    spread,
    z_window = 60,
    horizon = 10,
    entry_z = 1.0,
    min_pnl = 0.0,
):

    z = rolling_zscore(spread, window = z_window)

    direction = -np.sign(z)

    future_spread = spread.shift(-horizon)

    spread_change = future_spread - spread
    pnl = direction * spread_change

    entry = z.abs() >= entry_z

    labels = ((entry) & (pnl > min_pnl)).astype(float)

    labels = labels.iloc[:-horizon]

    labels = labels.dropna()

    return labels

def process_pair(etf1, etf2, price_data, lookback = 60):
    df = pd.DataFrame(index=price_data.index)
    df["etf1"] = price_data[etf1]
    df["etf2"] = price_data[etf2]

    df["hedge_ratio"] = (
        df["etf1"].rolling(lookback).cov(df["etf2"]) /
        df["etf2"].rolling(lookback).var()
    )

    df["spread"] = df["etf1"] - df["hedge_ratio"] * df["etf2"]
    spread_mean = df["spread"].rolling(lookback).mean()
    spread_std = df["spread"].rolling(lookback).std()
    df["zscore"] = (df["spread"] - spread_mean) / spread_std

    df["rolling_mean"] = spread_mean
    df["rolling_std"] = spread_std
    df["volatility"] = df["spread"].pct_change().rolling(lookback).std()

    for i in range(1, 6):
        df[f"spread_lag_{i}"] = df["spread"].shift(i)
        df[f"zscore_lag_{i}"] = df["zscore"].shift(i)

    labels = predict_mean_reversion_label(df['spread'])
    idx = df.index.intersection(labels.index)
    df = df.loc[idx].copy()
    df['target'] = labels.loc[idx]

    df["pair"] = f"{etf1}_{etf2}"

    return df.dropna()


feature_cols = [
    'spread', 'zscore',
    'rolling_mean', 'rolling_std', 'volatility',
    'spread_lag_1', 'zscore_lag_1',
    'spread_lag_2', 'zscore_lag_2',
    'spread_lag_3', 'zscore_lag_3',
    'spread_lag_4', 'zscore_lag_4',
    'spread_lag_5', 'zscore_lag_5'
]

param_grid = {
    'max_depth':       [4, 6, 8],
    'gamma':           [0, 1], 
    'learning_rate':   [0.01, 0.05],
    'min_child_weight':[1, 5]
}

cv = TimeSeriesSplit(n_splits = 5)

pair_models = {}

for etf1, etf2 in etf_pairs:
    pair_name = f"{etf1}_{etf2}"

    train_pair = process_pair(etf1, etf2, train_prices)
    test_pair = process_pair(etf1, etf2, test_prices)

    X_train, y_train = train_pair[feature_cols], train_pair["target"]
    X_test, y_test = test_pair[feature_cols], test_pair["target"]

    grid_search = GridSearchCV(
        estimator = XGBClassifier(
            objective = 'binary:logistic',
            eval_metric = 'logloss',
            random_state = 42,
            seed = 42,
            tree_method = 'hist',
            n_estimators = 300,
            subsample = 1.0,
            colsample_bytree = 1.0,
            colsample_bynode = 1.0
        ),
        param_grid = param_grid,
        cv = cv,
        scoring = 'f1',
        n_jobs = -1,
        verbose = 2
    )

    grid_search.fit(X_train, y_train)
    best_xgb = grid_search.best_estimator_
    pair_models[pair_name] = best_xgb

    print("\nBest Parameters:", grid_search.best_params_)

    y_pred = best_xgb.predict(X_test)
    y_pred_probs = best_xgb.predict_proba(X_test)[:, 1]

    print("\nClassification Report (Test Data):\n", classification_report(y_test, y_pred))
    print("Accuracy:", accuracy_score(y_test, y_pred))
    print("True Label Distribution:", Counter(y_test))
    print("Predicted Label Distribution:", Counter(y_pred))
    print("\nConfusion Matrix:\n", confusion_matrix(y_test, y_pred))

    importances = best_xgb.feature_importances_
    feat_imp_df = pd.DataFrame({'Feature': feature_cols, 'Importance': importances})
    feat_imp_df = feat_imp_df.sort_values(by = 'Importance', ascending = False)

    plt.figure(figsize = (10, 6))
    sns.barplot(data = feat_imp_df, x = 'Importance', y = 'Feature')
    plt.title('Feature Importances')
    plt.tight_layout()
    plt.show()
# Out:
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# [CV] END gamma=0, learning_rate=0.01, max_depth=4, min_child_weight=5; total time=   0.3s
# [CV] END gamma=0, learning_rate=0.01, max_depth=4, min_child_weight=1; total time=   0.4s
# [CV] END gamma=0, learning_rate=0.01, max_depth=4, min_child_weight=5; total time=   0.4s
# [CV] END gamma=0, learning_rate=0.01, max_depth=4, min_child_weight=1; total time=   0.6s
# [CV] END gamma=0, learning_rate=0.01, max_depth=4, min_child_weight=5; total time=   0.5s
# [CV] END gamma=0, learning_rate=0.01, max_depth=4, min_child_weight=1; total time=   0.7s
# [CV] END gamma=0, learning_rate=0.01, max_depth=4, min_child_weight=1; total time=   0.7s
# [CV] END gamma=0, learning_rate=0.01, max_depth=4, min_child_weight=1; total time=   0.7s
# [CV] END gamma=0, learning_rate=0.01, max_depth=6, min_child_weight=1; total time=   0.4s
# [CV] END gamma=0, learning_rate=0.01, max_depth=4, min_child_weight=5; total time=   0.5s
# [CV] END gamma=0, learning_rate=0.01, max_depth=4, min_child_weight=5; total time=   0.6s
# [CV] END gamma=0, learning_rate=0.01, max_depth=6, min_child_weight=5; total time=   0.2s
# [CV] END gamma=0, learning_rate=0.01, max_depth=6, min_child_weight=5; total time=   0.4s
# [CV] END gamma=0, learning_rate=0.01, max_depth=6, min_child_weight=1; total time=   0.8s
# [CV] END gamma=0, learning_rate=0.01, max_depth=6, min_child_weight=5; total time=   0.6s
# [CV] END gamma=0, learning_rate=0.01, max_depth=6, min_child_weight=1; total time=   1.0s
# [CV] END gamma=0, learning_rate=0.01, max_depth=6, min_child_weight=5; total time=   0.7s
# [CV] END gamma=0, learning_rate=0.01, max_depth=6, min_child_weight=1; total time=   1.0s
# [CV] END gamma=0, learning_rate=0.01, max_depth=8, min_child_weight=1; total time=   0.4s
# [CV] END gamma=0, learning_rate=0.01, max_depth=6, min_child_weight=5; total time=   0.8s
# [CV] END gamma=0, learning_rate=0.01, max_depth=6, min_child_weight=1; total time=   1.1s
# [CV] END gamma=0, learning_rate=0.01, max_depth=8, min_child_weight=5; total time=   0.2s
# [CV] END gamma=0, learning_rate=0.01, max_depth=8, min_child_weight=5; total time=   0.4s
# [CV] END gamma=0, learning_rate=0.01, max_depth=8, min_child_weight=1; total time=   0.8s
# [CV] END gamma=0, learning_rate=0.01, max_depth=8, min_child_weight=5; total time=   0.5s
# [CV] END gamma=0, learning_rate=0.05, max_depth=4, min_child_weight=1; total time=   0.2s
# [CV] END gamma=0, learning_rate=0.01, max_depth=8, min_child_weight=5; total time=   0.7s
# [CV] END gamma=0, learning_rate=0.01, max_depth=8, min_child_weight=1; total time=   1.1s
# [CV] END gamma=0, learning_rate=0.05, max_depth=4, min_child_weight=1; total time=   0.4s
# [CV] END gamma=0, learning_rate=0.01, max_depth=8, min_child_weight=5; total time=   0.8s
# [CV] END gamma=0, learning_rate=0.05, max_depth=4, min_child_weight=5; total time=   0.2s
# [CV] END gamma=0, learning_rate=0.01, max_depth=8, min_child_weight=1; total time=   1.2s
# [CV] END gamma=0, learning_rate=0.05, max_depth=4, min_child_weight=5; total time=   0.3s
# [CV] END gamma=0, learning_rate=0.05, max_depth=4, min_child_weight=1; total time=   0.6s
# [CV] END gamma=0, learning_rate=0.05, max_depth=4, min_child_weight=1; total time=   0.6s
# [CV] END gamma=0, learning_rate=0.01, max_depth=8, min_child_weight=1; total time=   1.4s
# [CV] END gamma=0, learning_rate=0.05, max_depth=4, min_child_weight=5; total time=   0.4s
# [CV] END gamma=0, learning_rate=0.05, max_depth=6, min_child_weight=1; total time=   0.3s
# [CV] END gamma=0, learning_rate=0.05, max_depth=4, min_child_weight=1; total time=   0.7s
# [CV] END gamma=0, learning_rate=0.05, max_depth=4, min_child_weight=5; total time=   0.5s
# [CV] END gamma=0, learning_rate=0.05, max_depth=4, min_child_weight=5; total time=   0.5s
# [CV] END gamma=0, learning_rate=0.05, max_depth=6, min_child_weight=5; total time=   0.2s
# [CV] END gamma=0, learning_rate=0.05, max_depth=6, min_child_weight=1; total time=   0.5s
# [CV] END gamma=0, learning_rate=0.05, max_depth=6, min_child_weight=5; total time=   0.3s
# [CV] END gamma=0, learning_rate=0.05, max_depth=6, min_child_weight=1; total time=   0.6s
# [CV] END gamma=0, learning_rate=0.05, max_depth=6, min_child_weight=5; total time=   0.4s
# [CV] END gamma=0, learning_rate=0.05, max_depth=8, min_child_weight=1; total time=   0.2s
# [CV] END gamma=0, learning_rate=0.05, max_depth=6, min_child_weight=1; total time=   0.7s
# [CV] END gamma=0, learning_rate=0.05, max_depth=6, min_child_weight=5; total time=   0.4s
# [CV] END gamma=0, learning_rate=0.05, max_depth=8, min_child_weight=1; total time=   0.5s
# [CV] END gamma=0, learning_rate=0.05, max_depth=8, min_child_weight=5; total time=   0.2s
# [CV] END gamma=0, learning_rate=0.05, max_depth=6, min_child_weight=5; total time=   0.6s
# [CV] END gamma=0, learning_rate=0.05, max_depth=6, min_child_weight=1; total time=   0.8s
# [CV] END gamma=0, learning_rate=0.05, max_depth=8, min_child_weight=5; total time=   0.3s
# [CV] END gamma=0, learning_rate=0.05, max_depth=8, min_child_weight=1; total time=   0.6s
# [CV] END gamma=0, learning_rate=0.05, max_depth=8, min_child_weight=5; total time=   0.4s
# [CV] END gamma=1, learning_rate=0.01, max_depth=4, min_child_weight=1; total time=   0.4s
# [CV] END gamma=0, learning_rate=0.05, max_depth=8, min_child_weight=1; total time=   0.8s
# [CV] END gamma=0, learning_rate=0.05, max_depth=8, min_child_weight=5; total time=   0.5s
# [CV] END gamma=0, learning_rate=0.05, max_depth=8, min_child_weight=5; total time=   0.7s
# [CV] END gamma=0, learning_rate=0.05, max_depth=8, min_child_weight=1; total time=   1.0s
# [CV] END gamma=1, learning_rate=0.01, max_depth=4, min_child_weight=5; total time=   0.4s
# [CV] END gamma=1, learning_rate=0.01, max_depth=4, min_child_weight=1; total time=   0.8s
# [CV] END gamma=1, learning_rate=0.01, max_depth=4, min_child_weight=5; total time=   0.5s
# [CV] END gamma=1, learning_rate=0.01, max_depth=4, min_child_weight=1; total time=   0.8s
# [CV] END gamma=1, learning_rate=0.01, max_depth=4, min_child_weight=1; total time=   0.8s
# [CV] END gamma=1, learning_rate=0.01, max_depth=4, min_child_weight=5; total time=   0.5s
# [CV] END gamma=1, learning_rate=0.01, max_depth=4, min_child_weight=1; total time=   0.8s
# [CV] END gamma=1, learning_rate=0.01, max_depth=6, min_child_weight=1; total time=   0.3s
# [CV] END gamma=1, learning_rate=0.01, max_depth=4, min_child_weight=5; total time=   0.5s
# [CV] END gamma=1, learning_rate=0.01, max_depth=4, min_child_weight=5; total time=   0.5s
# [CV] END gamma=1, learning_rate=0.01, max_depth=6, min_child_weight=5; total time=   0.2s
# [CV] END gamma=1, learning_rate=0.01, max_depth=6, min_child_weight=5; total time=   0.4s
# [CV] END gamma=1, learning_rate=0.01, max_depth=6, min_child_weight=1; total time=   0.6s
# [CV] END gamma=1, learning_rate=0.01, max_depth=6, min_child_weight=5; total time=   0.5s
# [CV] END gamma=1, learning_rate=0.01, max_depth=6, min_child_weight=1; total time=   0.8s
# [CV] END gamma=1, learning_rate=0.01, max_depth=6, min_child_weight=5; total time=   0.6s
# [CV] END gamma=1, learning_rate=0.01, max_depth=8, min_child_weight=1; total time=   0.3s
# [CV] END gamma=1, learning_rate=0.01, max_depth=6, min_child_weight=1; total time=   0.8s
# [CV] END gamma=1, learning_rate=0.01, max_depth=6, min_child_weight=5; total time=   0.7s
# [CV] END gamma=1, learning_rate=0.01, max_depth=6, min_child_weight=1; total time=   0.9s
# [CV] END gamma=1, learning_rate=0.01, max_depth=8, min_child_weight=5; total time=   0.2s
# [CV] END gamma=1, learning_rate=0.01, max_depth=8, min_child_weight=1; total time=   0.6s
# [CV] END gamma=1, learning_rate=0.01, max_depth=8, min_child_weight=5; total time=   0.4s
# [CV] END gamma=1, learning_rate=0.05, max_depth=4, min_child_weight=1; total time=   0.2s
# [CV] END gamma=1, learning_rate=0.01, max_depth=8, min_child_weight=1; total time=   0.8s
# [CV] END gamma=1, learning_rate=0.01, max_depth=8, min_child_weight=5; total time=   0.5s
# [CV] END gamma=1, learning_rate=0.05, max_depth=4, min_child_weight=1; total time=   0.2s
# [CV] END gamma=1, learning_rate=0.01, max_depth=8, min_child_weight=5; total time=   0.6s
# [CV] END gamma=1, learning_rate=0.05, max_depth=4, min_child_weight=1; total time=   0.3s
# [CV] END gamma=1, learning_rate=0.05, max_depth=4, min_child_weight=5; total time=   0.2s
# [CV] END gamma=1, learning_rate=0.01, max_depth=8, min_child_weight=1; total time=   0.9s
# [CV] END gamma=1, learning_rate=0.05, max_depth=4, min_child_weight=1; total time=   0.3s
# [CV] END gamma=1, learning_rate=0.01, max_depth=8, min_child_weight=5; total time=   0.7s
# [CV] END gamma=1, learning_rate=0.05, max_depth=4, min_child_weight=5; total time=   0.2s
# [CV] END gamma=1, learning_rate=0.05, max_depth=4, min_child_weight=1; total time=   0.3s
# [CV] END gamma=1, learning_rate=0.05, max_depth=4, min_child_weight=5; total time=   0.2s
# [CV] END gamma=1, learning_rate=0.05, max_depth=4, min_child_weight=5; total time=   0.3s
# [CV] END gamma=1, learning_rate=0.05, max_depth=6, min_child_weight=1; total time=   0.2s
# [CV] END gamma=1, learning_rate=0.05, max_depth=4, min_child_weight=5; total time=   0.3s
# [CV] END gamma=1, learning_rate=0.01, max_depth=8, min_child_weight=1; total time=   1.1s
# [CV] END gamma=1, learning_rate=0.05, max_depth=6, min_child_weight=1; total time=   0.3s
# [CV] END gamma=1, learning_rate=0.05, max_depth=6, min_child_weight=5; total time=   0.2s
# [CV] END gamma=1, learning_rate=0.05, max_depth=6, min_child_weight=1; total time=   0.3s
# [CV] END gamma=1, learning_rate=0.05, max_depth=6, min_child_weight=1; total time=   0.3s
# [CV] END gamma=1, learning_rate=0.05, max_depth=6, min_child_weight=5; total time=   0.2s
# [CV] END gamma=1, learning_rate=0.05, max_depth=6, min_child_weight=1; total time=   0.4s
# [CV] END gamma=1, learning_rate=0.05, max_depth=6, min_child_weight=5; total time=   0.3s
# [CV] END gamma=1, learning_rate=0.05, max_depth=6, min_child_weight=5; total time=   0.3s
# [CV] END gamma=1, learning_rate=0.05, max_depth=8, min_child_weight=1; total time=   0.2s
# [CV] END gamma=1, learning_rate=0.05, max_depth=8, min_child_weight=1; total time=   0.3s
# [CV] END gamma=1, learning_rate=0.05, max_depth=8, min_child_weight=5; total time=   0.2s
# [CV] END gamma=1, learning_rate=0.05, max_depth=6, min_child_weight=5; total time=   0.3s
# [CV] END gamma=1, learning_rate=0.05, max_depth=8, min_child_weight=1; total time=   0.3s
# [CV] END gamma=1, learning_rate=0.05, max_depth=8, min_child_weight=5; total time=   0.2s
# [CV] END gamma=1, learning_rate=0.05, max_depth=8, min_child_weight=1; total time=   0.3s
# [CV] END gamma=1, learning_rate=0.05, max_depth=8, min_child_weight=5; total time=   0.2s
# [CV] END gamma=1, learning_rate=0.05, max_depth=8, min_child_weight=1; total time=   0.3s
# [CV] END gamma=1, learning_rate=0.05, max_depth=8, min_child_weight=5; total time=   0.2s
# [CV] END gamma=1, learning_rate=0.05, max_depth=8, min_child_weight=5; total time=   0.2s
#
# Best Parameters: {'gamma': 0, 'learning_rate': 0.01, 'max_depth': 4, 'min_child_weight': 5}
#
# Classification Report (Test Data):
#                precision    recall  f1-score   support
#
#          0.0       0.91      0.79      0.85       818
#          1.0       0.59      0.80      0.68       306
#
#     accuracy                           0.80      1124
#    macro avg       0.75      0.80      0.76      1124
# weighted avg       0.83      0.80      0.80      1124
#
# Accuracy: 0.7953736654804271
# True Label Distribution: Counter({0.0: 818, 1.0: 306})
# Predicted Label Distribution: Counter({np.int64(0): 712, np.int64(1): 412})
#
# Confusion Matrix:
#  [[650 168]
#  [ 62 244]]
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# [CV] END gamma=0, learning_rate=0.01, max_depth=4, min_child_weight=5; total time=   0.2s
# [CV] END gamma=0, learning_rate=0.01, max_depth=4, min_child_weight=1; total time=   0.3s
# [CV] END gamma=0, learning_rate=0.01, max_depth=4, min_child_weight=5; total time=   0.4s
# [CV] END gamma=0, learning_rate=0.01, max_depth=4, min_child_weight=5; total time=   0.5s
# [CV] END gamma=0, learning_rate=0.01, max_depth=4, min_child_weight=1; total time=   0.5s
# [CV] END gamma=0, learning_rate=0.01, max_depth=4, min_child_weight=1; total time=   0.6s
# [CV] END gamma=0, learning_rate=0.01, max_depth=4, min_child_weight=1; total time=   0.6s
# [CV] END gamma=0, learning_rate=0.01, max_depth=4, min_child_weight=1; total time=   0.6s
# [CV] END gamma=0, learning_rate=0.01, max_depth=4, min_child_weight=5; total time=   0.5s
# [CV] END gamma=0, learning_rate=0.01, max_depth=6, min_child_weight=1; total time=   0.3s
# [CV] END gamma=0, learning_rate=0.01, max_depth=4, min_child_weight=5; total time=   0.5s
# [CV] END gamma=0, learning_rate=0.01, max_depth=6, min_child_weight=5; total time=   0.2s
# [CV] END gamma=0, learning_rate=0.01, max_depth=6, min_child_weight=5; total time=   0.4s
# [CV] END gamma=0, learning_rate=0.01, max_depth=6, min_child_weight=1; total time=   0.7s
# [CV] END gamma=0, learning_rate=0.01, max_depth=6, min_child_weight=5; total time=   0.5s
# [CV] END gamma=0, learning_rate=0.01, max_depth=6, min_child_weight=1; total time=   0.8s
# [CV] END gamma=0, learning_rate=0.01, max_depth=6, min_child_weight=5; total time=   0.6s
# [CV] END gamma=0, learning_rate=0.01, max_depth=8, min_child_weight=1; total time=   0.3s
# [CV] END gamma=0, learning_rate=0.01, max_depth=6, min_child_weight=1; total time=   0.9s
# [CV] END gamma=0, learning_rate=0.01, max_depth=6, min_child_weight=5; total time=   0.7s
# [CV] END gamma=0, learning_rate=0.01, max_depth=6, min_child_weight=1; total time=   1.0s
# [CV] END gamma=0, learning_rate=0.01, max_depth=8, min_child_weight=5; total time=   0.2s
# [CV] END gamma=0, learning_rate=0.01, max_depth=8, min_child_weight=5; total time=   0.4s
# [CV] END gamma=0, learning_rate=0.01, max_depth=8, min_child_weight=1; total time=   0.7s
# [CV] END gamma=0, learning_rate=0.01, max_depth=8, min_child_weight=5; total time=   0.5s
# [CV] END gamma=0, learning_rate=0.05, max_depth=4, min_child_weight=1; total time=   0.2s
# [CV] END gamma=0, learning_rate=0.01, max_depth=8, min_child_weight=5; total time=   0.6s
# [CV] END gamma=0, learning_rate=0.01, max_depth=8, min_child_weight=1; total time=   1.0s
# [CV] END gamma=0, learning_rate=0.05, max_depth=4, min_child_weight=1; total time=   0.3s
# [CV] END gamma=0, learning_rate=0.01, max_depth=8, min_child_weight=5; total time=   0.7s
# [CV] END gamma=0, learning_rate=0.05, max_depth=4, min_child_weight=5; total time=   0.2s
# [CV] END gamma=0, learning_rate=0.01, max_depth=8, min_child_weight=1; total time=   1.0s
# [CV] END gamma=0, learning_rate=0.05, max_depth=4, min_child_weight=5; total time=   0.2s
# [CV] END gamma=0, learning_rate=0.05, max_depth=4, min_child_weight=1; total time=   0.5s
# [CV] END gamma=0, learning_rate=0.05, max_depth=4, min_child_weight=1; total time=   0.5s
# [CV] END gamma=0, learning_rate=0.01, max_depth=8, min_child_weight=1; total time=   1.2s
# [CV] END gamma=0, learning_rate=0.05, max_depth=6, min_child_weight=1; total time=   0.2s
# [CV] END gamma=0, learning_rate=0.05, max_depth=4, min_child_weight=5; total time=   0.3s
# [CV] END gamma=0, learning_rate=0.05, max_depth=4, min_child_weight=1; total time=   0.6s
# [CV] END gamma=0, learning_rate=0.05, max_depth=4, min_child_weight=5; total time=   0.4s
# [CV] END gamma=0, learning_rate=0.05, max_depth=4, min_child_weight=5; total time=   0.4s
# [CV] END gamma=0, learning_rate=0.05, max_depth=6, min_child_weight=5; total time=   0.2s
# [CV] END gamma=0, learning_rate=0.05, max_depth=6, min_child_weight=1; total time=   0.4s
# [CV] END gamma=0, learning_rate=0.05, max_depth=6, min_child_weight=5; total time=   0.3s
# [CV] END gamma=0, learning_rate=0.05, max_depth=6, min_child_weight=5; total time=   0.4s
# [CV] END gamma=0, learning_rate=0.05, max_depth=8, min_child_weight=1; total time=   0.2s
# [CV] END gamma=0, learning_rate=0.05, max_depth=6, min_child_weight=1; total time=   0.6s
# [CV] END gamma=0, learning_rate=0.05, max_depth=6, min_child_weight=1; total time=   0.6s
# [CV] END gamma=0, learning_rate=0.05, max_depth=6, min_child_weight=5; total time=   0.4s
# [CV] END gamma=0, learning_rate=0.05, max_depth=6, min_child_weight=5; total time=   0.5s
# [CV] END gamma=0, learning_rate=0.05, max_depth=8, min_child_weight=1; total time=   0.4s
# [CV] END gamma=0, learning_rate=0.05, max_depth=8, min_child_weight=5; total time=   0.2s
# [CV] END gamma=0, learning_rate=0.05, max_depth=6, min_child_weight=1; total time=   0.7s
# [CV] END gamma=0, learning_rate=0.05, max_depth=8, min_child_weight=5; total time=   0.3s
# [CV] END gamma=0, learning_rate=0.05, max_depth=8, min_child_weight=1; total time=   0.6s
# [CV] END gamma=0, learning_rate=0.05, max_depth=8, min_child_weight=5; total time=   0.4s
# [CV] END gamma=1, learning_rate=0.01, max_depth=4, min_child_weight=1; total time=   0.3s
# [CV] END gamma=0, learning_rate=0.05, max_depth=8, min_child_weight=1; total time=   0.6s
# [CV] END gamma=0, learning_rate=0.05, max_depth=8, min_child_weight=5; total time=   0.4s
# [CV] END gamma=0, learning_rate=0.05, max_depth=8, min_child_weight=5; total time=   0.5s
# [CV] END gamma=0, learning_rate=0.05, max_depth=8, min_child_weight=1; total time=   0.8s
# [CV] END gamma=1, learning_rate=0.01, max_depth=4, min_child_weight=5; total time=   0.2s
# [CV] END gamma=1, learning_rate=0.01, max_depth=4, min_child_weight=1; total time=   0.5s
# [CV] END gamma=1, learning_rate=0.01, max_depth=4, min_child_weight=5; total time=   0.4s
# [CV] END gamma=1, learning_rate=0.01, max_depth=4, min_child_weight=1; total time=   0.6s
# [CV] END gamma=1, learning_rate=0.01, max_depth=4, min_child_weight=1; total time=   0.6s
# [CV] END gamma=1, learning_rate=0.01, max_depth=4, min_child_weight=1; total time=   0.6s
# [CV] END gamma=1, learning_rate=0.01, max_depth=4, min_child_weight=5; total time=   0.4s
# [CV] END gamma=1, learning_rate=0.01, max_depth=6, min_child_weight=1; total time=   0.3s
# [CV] END gamma=1, learning_rate=0.01, max_depth=4, min_child_weight=5; total time=   0.5s
# [CV] END gamma=1, learning_rate=0.01, max_depth=4, min_child_weight=5; total time=   0.5s
# [CV] END gamma=1, learning_rate=0.01, max_depth=6, min_child_weight=5; total time=   0.2s
# [CV] END gamma=1, learning_rate=0.01, max_depth=6, min_child_weight=5; total time=   0.4s
# [CV] END gamma=1, learning_rate=0.01, max_depth=6, min_child_weight=1; total time=   0.6s
# [CV] END gamma=1, learning_rate=0.01, max_depth=6, min_child_weight=5; total time=   0.5s
# [CV] END gamma=1, learning_rate=0.01, max_depth=6, min_child_weight=1; total time=   0.8s
# [CV] END gamma=1, learning_rate=0.01, max_depth=6, min_child_weight=5; total time=   0.6s
# [CV] END gamma=1, learning_rate=0.01, max_depth=8, min_child_weight=1; total time=   0.3s
# [CV] END gamma=1, learning_rate=0.01, max_depth=6, min_child_weight=1; total time=   0.8s
# [CV] END gamma=1, learning_rate=0.01, max_depth=6, min_child_weight=5; total time=   0.7s
# [CV] END gamma=1, learning_rate=0.01, max_depth=6, min_child_weight=1; total time=   0.9s
# [CV] END gamma=1, learning_rate=0.01, max_depth=8, min_child_weight=5; total time=   0.2s
# [CV] END gamma=1, learning_rate=0.01, max_depth=8, min_child_weight=1; total time=   0.6s
# [CV] END gamma=1, learning_rate=0.01, max_depth=8, min_child_weight=5; total time=   0.4s
# [CV] END gamma=1, learning_rate=0.05, max_depth=4, min_child_weight=1; total time=   0.2s
# [CV] END gamma=1, learning_rate=0.01, max_depth=8, min_child_weight=5; total time=   0.5s
# [CV] END gamma=1, learning_rate=0.05, max_depth=4, min_child_weight=1; total time=   0.2s
# [CV] END gamma=1, learning_rate=0.01, max_depth=8, min_child_weight=1; total time=   0.9s
# [CV] END gamma=1, learning_rate=0.01, max_depth=8, min_child_weight=5; total time=   0.6s
# [CV] END gamma=1, learning_rate=0.05, max_depth=4, min_child_weight=1; total time=   0.3s
# [CV] END gamma=1, learning_rate=0.05, max_depth=4, min_child_weight=5; total time=   0.1s
# [CV] END gamma=1, learning_rate=0.01, max_depth=8, min_child_weight=5; total time=   0.7s
# [CV] END gamma=1, learning_rate=0.01, max_depth=8, min_child_weight=1; total time=   0.9s
# [CV] END gamma=1, learning_rate=0.05, max_depth=4, min_child_weight=1; total time=   0.3s
# [CV] END gamma=1, learning_rate=0.05, max_depth=4, min_child_weight=5; total time=   0.2s
# [CV] END gamma=1, learning_rate=0.05, max_depth=4, min_child_weight=1; total time=   0.3s
# [CV] END gamma=1, learning_rate=0.05, max_depth=4, min_child_weight=5; total time=   0.2s
# [CV] END gamma=1, learning_rate=0.01, max_depth=8, min_child_weight=1; total time=   1.1s
# [CV] END gamma=1, learning_rate=0.05, max_depth=6, min_child_weight=1; total time=   0.2s
# [CV] END gamma=1, learning_rate=0.05, max_depth=4, min_child_weight=5; total time=   0.3s
# [CV] END gamma=1, learning_rate=0.05, max_depth=4, min_child_weight=5; total time=   0.3s
# [CV] END gamma=1, learning_rate=0.05, max_depth=6, min_child_weight=5; total time=   0.1s
# [CV] END gamma=1, learning_rate=0.05, max_depth=6, min_child_weight=1; total time=   0.3s
# [CV] END gamma=1, learning_rate=0.05, max_depth=6, min_child_weight=1; total time=   0.3s
# [CV] END gamma=1, learning_rate=0.05, max_depth=6, min_child_weight=5; total time=   0.2s
# [CV] END gamma=1, learning_rate=0.05, max_depth=6, min_child_weight=1; total time=   0.3s
# [CV] END gamma=1, learning_rate=0.05, max_depth=6, min_child_weight=5; total time=   0.2s
# [CV] END gamma=1, learning_rate=0.05, max_depth=6, min_child_weight=1; total time=   0.4s
# [CV] END gamma=1, learning_rate=0.05, max_depth=8, min_child_weight=1; total time=   0.2s
# [CV] END gamma=1, learning_rate=0.05, max_depth=6, min_child_weight=5; total time=   0.3s
# [CV] END gamma=1, learning_rate=0.05, max_depth=6, min_child_weight=5; total time=   0.3s
# [CV] END gamma=1, learning_rate=0.05, max_depth=8, min_child_weight=1; total time=   0.2s
# [CV] END gamma=1, learning_rate=0.05, max_depth=8, min_child_weight=5; total time=   0.1s
# [CV] END gamma=1, learning_rate=0.05, max_depth=8, min_child_weight=1; total time=   0.3s
# [CV] END gamma=1, learning_rate=0.05, max_depth=8, min_child_weight=5; total time=   0.2s
# [CV] END gamma=1, learning_rate=0.05, max_depth=8, min_child_weight=1; total time=   0.3s
# [CV] END gamma=1, learning_rate=0.05, max_depth=8, min_child_weight=5; total time=   0.2s
# [CV] END gamma=1, learning_rate=0.05, max_depth=8, min_child_weight=1; total time=   0.3s
# [CV] END gamma=1, learning_rate=0.05, max_depth=8, min_child_weight=5; total time=   0.2s
# [CV] END gamma=1, learning_rate=0.05, max_depth=8, min_child_weight=5; total time=   0.2s
#
# Best Parameters: {'gamma': 1, 'learning_rate': 0.05, 'max_depth': 8, 'min_child_weight': 5}
#
# Classification Report (Test Data):
#                precision    recall  f1-score   support
#
#          0.0       0.89      0.76      0.82       826
#          1.0       0.52      0.73      0.61       298
#
#     accuracy                           0.75      1124
#    macro avg       0.71      0.75      0.72      1124
# weighted avg       0.79      0.75      0.76      1124
#
# Accuracy: 0.7526690391459074
# True Label Distribution: Counter({0.0: 826, 1.0: 298})
# Predicted Label Distribution: Counter({np.int64(0): 706, np.int64(1): 418})
#
# Confusion Matrix:
#  [[627 199]
#  [ 79 219]]
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# [CV] END gamma=0, learning_rate=0.01, max_depth=4, min_child_weight=5; total time=   0.2s
# [CV] END gamma=0, learning_rate=0.01, max_depth=4, min_child_weight=1; total time=   0.3s
# [CV] END gamma=0, learning_rate=0.01, max_depth=4, min_child_weight=5; total time=   0.4s
# [CV] END gamma=0, learning_rate=0.01, max_depth=4, min_child_weight=5; total time=   0.5s
# [CV] END gamma=0, learning_rate=0.01, max_depth=4, min_child_weight=1; total time=   0.5s
# [CV] END gamma=0, learning_rate=0.01, max_depth=4, min_child_weight=1; total time=   0.6s
# [CV] END gamma=0, learning_rate=0.01, max_depth=4, min_child_weight=1; total time=   0.6s
# [CV] END gamma=0, learning_rate=0.01, max_depth=4, min_child_weight=1; total time=   0.7s
# [CV] END gamma=0, learning_rate=0.01, max_depth=4, min_child_weight=5; total time=   0.5s
# [CV] END gamma=0, learning_rate=0.01, max_depth=6, min_child_weight=1; total time=   0.4s
# [CV] END gamma=0, learning_rate=0.01, max_depth=4, min_child_weight=5; total time=   0.5s
# [CV] END gamma=0, learning_rate=0.01, max_depth=6, min_child_weight=5; total time=   0.2s
# [CV] END gamma=0, learning_rate=0.01, max_depth=6, min_child_weight=5; total time=   0.4s
# [CV] END gamma=0, learning_rate=0.01, max_depth=6, min_child_weight=1; total time=   0.7s
# [CV] END gamma=0, learning_rate=0.01, max_depth=6, min_child_weight=5; total time=   0.5s
# [CV] END gamma=0, learning_rate=0.01, max_depth=6, min_child_weight=1; total time=   0.9s
# [CV] END gamma=0, learning_rate=0.01, max_depth=6, min_child_weight=5; total time=   0.5s
# [CV] END gamma=0, learning_rate=0.01, max_depth=8, min_child_weight=1; total time=   0.4s
# [CV] END gamma=0, learning_rate=0.01, max_depth=6, min_child_weight=1; total time=   0.9s
# [CV] END gamma=0, learning_rate=0.01, max_depth=6, min_child_weight=5; total time=   0.7s
# [CV] END gamma=0, learning_rate=0.01, max_depth=6, min_child_weight=1; total time=   1.0s
# [CV] END gamma=0, learning_rate=0.01, max_depth=8, min_child_weight=5; total time=   0.2s
# [CV] END gamma=0, learning_rate=0.01, max_depth=8, min_child_weight=1; total time=   0.7s
# [CV] END gamma=0, learning_rate=0.01, max_depth=8, min_child_weight=5; total time=   0.4s
# [CV] END gamma=0, learning_rate=0.01, max_depth=8, min_child_weight=5; total time=   0.5s
# [CV] END gamma=0, learning_rate=0.05, max_depth=4, min_child_weight=1; total time=   0.2s
# [CV] END gamma=0, learning_rate=0.01, max_depth=8, min_child_weight=1; total time=   0.9s
# [CV] END gamma=0, learning_rate=0.01, max_depth=8, min_child_weight=5; total time=   0.6s
# [CV] END gamma=0, learning_rate=0.05, max_depth=4, min_child_weight=1; total time=   0.4s
# [CV] END gamma=0, learning_rate=0.01, max_depth=8, min_child_weight=5; total time=   0.7s
# [CV] END gamma=0, learning_rate=0.01, max_depth=8, min_child_weight=1; total time=   1.0s
# [CV] END gamma=0, learning_rate=0.05, max_depth=4, min_child_weight=5; total time=   0.2s
# [CV] END gamma=0, learning_rate=0.05, max_depth=4, min_child_weight=1; total time=   0.4s
# [CV] END gamma=0, learning_rate=0.05, max_depth=4, min_child_weight=5; total time=   0.3s
# [CV] END gamma=0, learning_rate=0.05, max_depth=4, min_child_weight=1; total time=   0.5s
# [CV] END gamma=0, learning_rate=0.01, max_depth=8, min_child_weight=1; total time=   1.2s
# [CV] END gamma=0, learning_rate=0.05, max_depth=6, min_child_weight=1; total time=   0.2s
# [CV] END gamma=0, learning_rate=0.05, max_depth=4, min_child_weight=5; total time=   0.3s
# [CV] END gamma=0, learning_rate=0.05, max_depth=4, min_child_weight=1; total time=   0.5s
# [CV] END gamma=0, learning_rate=0.05, max_depth=4, min_child_weight=5; total time=   0.4s
# [CV] END gamma=0, learning_rate=0.05, max_depth=4, min_child_weight=5; total time=   0.4s
# [CV] END gamma=0, learning_rate=0.05, max_depth=6, min_child_weight=5; total time=   0.2s
# [CV] END gamma=0, learning_rate=0.05, max_depth=6, min_child_weight=1; total time=   0.4s
# [CV] END gamma=0, learning_rate=0.05, max_depth=6, min_child_weight=5; total time=   0.3s
# [CV] END gamma=0, learning_rate=0.05, max_depth=6, min_child_weight=5; total time=   0.4s
# [CV] END gamma=0, learning_rate=0.05, max_depth=6, min_child_weight=1; total time=   0.5s
# [CV] END gamma=0, learning_rate=0.05, max_depth=8, min_child_weight=1; total time=   0.3s
# [CV] END gamma=0, learning_rate=0.05, max_depth=6, min_child_weight=1; total time=   0.6s
# [CV] END gamma=0, learning_rate=0.05, max_depth=6, min_child_weight=5; total time=   0.4s
# [CV] END gamma=0, learning_rate=0.05, max_depth=6, min_child_weight=5; total time=   0.5s
# [CV] END gamma=0, learning_rate=0.05, max_depth=8, min_child_weight=5; total time=   0.2s
# [CV] END gamma=0, learning_rate=0.05, max_depth=6, min_child_weight=1; total time=   0.8s
# [CV] END gamma=0, learning_rate=0.05, max_depth=8, min_child_weight=1; total time=   0.5s
# [CV] END gamma=0, learning_rate=0.05, max_depth=8, min_child_weight=5; total time=   0.3s
# [CV] END gamma=0, learning_rate=0.05, max_depth=8, min_child_weight=1; total time=   0.6s
# [CV] END gamma=0, learning_rate=0.05, max_depth=8, min_child_weight=5; total time=   0.4s
# [CV] END gamma=0, learning_rate=0.05, max_depth=8, min_child_weight=1; total time=   0.7s
# [CV] END gamma=1, learning_rate=0.01, max_depth=4, min_child_weight=1; total time=   0.3s
# [CV] END gamma=0, learning_rate=0.05, max_depth=8, min_child_weight=5; total time=   0.4s
# [CV] END gamma=0, learning_rate=0.05, max_depth=8, min_child_weight=1; total time=   0.8s
# [CV] END gamma=0, learning_rate=0.05, max_depth=8, min_child_weight=5; total time=   0.5s
# [CV] END gamma=1, learning_rate=0.01, max_depth=4, min_child_weight=5; total time=   0.2s
# [CV] END gamma=1, learning_rate=0.01, max_depth=4, min_child_weight=1; total time=   0.6s
# [CV] END gamma=1, learning_rate=0.01, max_depth=4, min_child_weight=5; total time=   0.4s
# [CV] END gamma=1, learning_rate=0.01, max_depth=4, min_child_weight=1; total time=   0.6s
# [CV] END gamma=1, learning_rate=0.01, max_depth=4, min_child_weight=1; total time=   0.6s
# [CV] END gamma=1, learning_rate=0.01, max_depth=4, min_child_weight=5; total time=   0.5s
# [CV] END gamma=1, learning_rate=0.01, max_depth=4, min_child_weight=5; total time=   0.5s
# [CV] END gamma=1, learning_rate=0.01, max_depth=6, min_child_weight=1; total time=   0.3s
# [CV] END gamma=1, learning_rate=0.01, max_depth=4, min_child_weight=1; total time=   0.7s
# [CV] END gamma=1, learning_rate=0.01, max_depth=4, min_child_weight=5; total time=   0.5s
# [CV] END gamma=1, learning_rate=0.01, max_depth=6, min_child_weight=5; total time=   0.2s
# [CV] END gamma=1, learning_rate=0.01, max_depth=6, min_child_weight=1; total time=   0.6s
# [CV] END gamma=1, learning_rate=0.01, max_depth=6, min_child_weight=5; total time=   0.4s
# [CV] END gamma=1, learning_rate=0.01, max_depth=6, min_child_weight=5; total time=   0.5s
# [CV] END gamma=1, learning_rate=0.01, max_depth=6, min_child_weight=5; total time=   0.6s
# [CV] END gamma=1, learning_rate=0.01, max_depth=6, min_child_weight=1; total time=   0.8s
# [CV] END gamma=1, learning_rate=0.01, max_depth=8, min_child_weight=1; total time=   0.3s
# [CV] END gamma=1, learning_rate=0.01, max_depth=6, min_child_weight=1; total time=   0.8s
# [CV] END gamma=1, learning_rate=0.01, max_depth=6, min_child_weight=5; total time=   0.7s
# [CV] END gamma=1, learning_rate=0.01, max_depth=6, min_child_weight=1; total time=   0.9s
# [CV] END gamma=1, learning_rate=0.01, max_depth=8, min_child_weight=5; total time=   0.3s
# [CV] END gamma=1, learning_rate=0.01, max_depth=8, min_child_weight=1; total time=   0.7s
# [CV] END gamma=1, learning_rate=0.01, max_depth=8, min_child_weight=5; total time=   0.5s
# [CV] END gamma=1, learning_rate=0.05, max_depth=4, min_child_weight=1; total time=   0.2s
# [CV] END gamma=1, learning_rate=0.01, max_depth=8, min_child_weight=5; total time=   0.6s
# [CV] END gamma=1, learning_rate=0.01, max_depth=8, min_child_weight=1; total time=   1.0s
# [CV] END gamma=1, learning_rate=0.05, max_depth=4, min_child_weight=1; total time=   0.3s
# [CV] END gamma=1, learning_rate=0.01, max_depth=8, min_child_weight=5; total time=   0.7s
# [CV] END gamma=1, learning_rate=0.05, max_depth=4, min_child_weight=1; total time=   0.3s
# [CV] END gamma=1, learning_rate=0.01, max_depth=8, min_child_weight=1; total time=   1.1s
# [CV] END gamma=1, learning_rate=0.05, max_depth=4, min_child_weight=5; total time=   0.2s
# [CV] END gamma=1, learning_rate=0.05, max_depth=4, min_child_weight=1; total time=   0.4s
# [CV] END gamma=1, learning_rate=0.01, max_depth=8, min_child_weight=5; total time=   0.8s
# [CV] END gamma=1, learning_rate=0.05, max_depth=4, min_child_weight=5; total time=   0.2s
# [CV] END gamma=1, learning_rate=0.05, max_depth=4, min_child_weight=1; total time=   0.4s
# [CV] END gamma=1, learning_rate=0.05, max_depth=4, min_child_weight=5; total time=   0.2s
# [CV] END gamma=1, learning_rate=0.01, max_depth=8, min_child_weight=1; total time=   1.3s
# [CV] END gamma=1, learning_rate=0.05, max_depth=4, min_child_weight=5; total time=   0.3s
# [CV] END gamma=1, learning_rate=0.05, max_depth=6, min_child_weight=1; total time=   0.2s
# [CV] END gamma=1, learning_rate=0.05, max_depth=4, min_child_weight=5; total time=   0.3s
# [CV] END gamma=1, learning_rate=0.05, max_depth=6, min_child_weight=1; total time=   0.3s
# [CV] END gamma=1, learning_rate=0.05, max_depth=6, min_child_weight=5; total time=   0.2s
# [CV] END gamma=1, learning_rate=0.05, max_depth=6, min_child_weight=1; total time=   0.3s
# [CV] END gamma=1, learning_rate=0.05, max_depth=6, min_child_weight=1; total time=   0.3s
# [CV] END gamma=1, learning_rate=0.05, max_depth=6, min_child_weight=5; total time=   0.2s
# [CV] END gamma=1, learning_rate=0.05, max_depth=6, min_child_weight=5; total time=   0.2s
# [CV] END gamma=1, learning_rate=0.05, max_depth=6, min_child_weight=1; total time=   0.4s
# [CV] END gamma=1, learning_rate=0.05, max_depth=8, min_child_weight=1; total time=   0.2s
# [CV] END gamma=1, learning_rate=0.05, max_depth=6, min_child_weight=5; total time=   0.3s
# [CV] END gamma=1, learning_rate=0.05, max_depth=6, min_child_weight=5; total time=   0.4s
# [CV] END gamma=1, learning_rate=0.05, max_depth=8, min_child_weight=1; total time=   0.3s
# [CV] END gamma=1, learning_rate=0.05, max_depth=8, min_child_weight=5; total time=   0.2s
# [CV] END gamma=1, learning_rate=0.05, max_depth=8, min_child_weight=1; total time=   0.4s
# [CV] END gamma=1, learning_rate=0.05, max_depth=8, min_child_weight=5; total time=   0.3s
# [CV] END gamma=1, learning_rate=0.05, max_depth=8, min_child_weight=1; total time=   0.4s
# [CV] END gamma=1, learning_rate=0.05, max_depth=8, min_child_weight=5; total time=   0.3s
# [CV] END gamma=1, learning_rate=0.05, max_depth=8, min_child_weight=1; total time=   0.4s
# [CV] END gamma=1, learning_rate=0.05, max_depth=8, min_child_weight=5; total time=   0.2s
# [CV] END gamma=1, learning_rate=0.05, max_depth=8, min_child_weight=5; total time=   0.3s
#
# Best Parameters: {'gamma': 0, 'learning_rate': 0.05, 'max_depth': 8, 'min_child_weight': 5}
#
# Classification Report (Test Data):
#                precision    recall  f1-score   support
#
#          0.0       0.92      0.76      0.83       828
#          1.0       0.55      0.82      0.66       296
#
#     accuracy                           0.78      1124
#    macro avg       0.74      0.79      0.75      1124
# weighted avg       0.83      0.78      0.79      1124
#
# Accuracy: 0.7758007117437722
# True Label Distribution: Counter({0.0: 828, 1.0: 296})
# Predicted Label Distribution: Counter({np.int64(0): 680, np.int64(1): 444})
#
# Confusion Matrix:
#  [[628 200]
#  [ 52 244]]
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# [CV] END gamma=0, learning_rate=0.01, max_depth=4, min_child_weight=5; total time=   0.2s
# [CV] END gamma=0, learning_rate=0.01, max_depth=4, min_child_weight=1; total time=   0.3s
# [CV] END gamma=0, learning_rate=0.01, max_depth=4, min_child_weight=5; total time=   0.4s
# [CV] END gamma=0, learning_rate=0.01, max_depth=4, min_child_weight=1; total time=   0.5s
# [CV] END gamma=0, learning_rate=0.01, max_depth=4, min_child_weight=5; total time=   0.5s
# [CV] END gamma=0, learning_rate=0.01, max_depth=4, min_child_weight=1; total time=   0.6s
# [CV] END gamma=0, learning_rate=0.01, max_depth=4, min_child_weight=1; total time=   0.6s
# [CV] END gamma=0, learning_rate=0.01, max_depth=4, min_child_weight=1; total time=   0.7s
# [CV] END gamma=0, learning_rate=0.01, max_depth=4, min_child_weight=5; total time=   0.6s
# [CV] END gamma=0, learning_rate=0.01, max_depth=6, min_child_weight=1; total time=   0.4s
# [CV] END gamma=0, learning_rate=0.01, max_depth=4, min_child_weight=5; total time=   0.6s
# [CV] END gamma=0, learning_rate=0.01, max_depth=6, min_child_weight=5; total time=   0.2s
# [CV] END gamma=0, learning_rate=0.01, max_depth=6, min_child_weight=5; total time=   0.4s
# [CV] END gamma=0, learning_rate=0.01, max_depth=6, min_child_weight=1; total time=   0.8s
# [CV] END gamma=0, learning_rate=0.01, max_depth=6, min_child_weight=5; total time=   0.5s
# [CV] END gamma=0, learning_rate=0.01, max_depth=6, min_child_weight=1; total time=   0.9s
# [CV] END gamma=0, learning_rate=0.01, max_depth=6, min_child_weight=5; total time=   0.7s
# [CV] END gamma=0, learning_rate=0.01, max_depth=8, min_child_weight=1; total time=   0.4s
# [CV] END gamma=0, learning_rate=0.01, max_depth=6, min_child_weight=5; total time=   0.8s
# [CV] END gamma=0, learning_rate=0.01, max_depth=6, min_child_weight=1; total time=   1.1s
# [CV] END gamma=0, learning_rate=0.01, max_depth=6, min_child_weight=1; total time=   1.2s
# [CV] END gamma=0, learning_rate=0.01, max_depth=8, min_child_weight=5; total time=   0.2s
# [CV] END gamma=0, learning_rate=0.01, max_depth=8, min_child_weight=1; total time=   0.8s
# [CV] END gamma=0, learning_rate=0.01, max_depth=8, min_child_weight=5; total time=   0.4s
# [CV] END gamma=0, learning_rate=0.01, max_depth=8, min_child_weight=5; total time=   0.5s
# [CV] END gamma=0, learning_rate=0.05, max_depth=4, min_child_weight=1; total time=   0.2s
# [CV] END gamma=0, learning_rate=0.01, max_depth=8, min_child_weight=1; total time=   1.0s
# [CV] END gamma=0, learning_rate=0.05, max_depth=4, min_child_weight=1; total time=   0.4s
# [CV] END gamma=0, learning_rate=0.01, max_depth=8, min_child_weight=5; total time=   0.7s
# [CV] END gamma=0, learning_rate=0.01, max_depth=8, min_child_weight=5; total time=   0.8s
# [CV] END gamma=0, learning_rate=0.05, max_depth=4, min_child_weight=5; total time=   0.2s
# [CV] END gamma=0, learning_rate=0.01, max_depth=8, min_child_weight=1; total time=   1.2s
# [CV] END gamma=0, learning_rate=0.05, max_depth=4, min_child_weight=1; total time=   0.6s
# [CV] END gamma=0, learning_rate=0.05, max_depth=4, min_child_weight=5; total time=   0.3s
# [CV] END gamma=0, learning_rate=0.05, max_depth=4, min_child_weight=1; total time=   0.6s
# [CV] END gamma=0, learning_rate=0.05, max_depth=4, min_child_weight=1; total time=   0.6s
# [CV] END gamma=0, learning_rate=0.01, max_depth=8, min_child_weight=1; total time=   1.4s
# [CV] END gamma=0, learning_rate=0.05, max_depth=6, min_child_weight=1; total time=   0.2s
# [CV] END gamma=0, learning_rate=0.05, max_depth=4, min_child_weight=5; total time=   0.4s
# [CV] END gamma=0, learning_rate=0.05, max_depth=4, min_child_weight=5; total time=   0.4s
# [CV] END gamma=0, learning_rate=0.05, max_depth=6, min_child_weight=5; total time=   0.2s
# [CV] END gamma=0, learning_rate=0.05, max_depth=4, min_child_weight=5; total time=   0.5s
# [CV] END gamma=0, learning_rate=0.05, max_depth=6, min_child_weight=1; total time=   0.4s
# [CV] END gamma=0, learning_rate=0.05, max_depth=6, min_child_weight=5; total time=   0.3s
# [CV] END gamma=0, learning_rate=0.05, max_depth=8, min_child_weight=1; total time=   0.2s
# [CV] END gamma=0, learning_rate=0.05, max_depth=6, min_child_weight=1; total time=   0.6s
# [CV] END gamma=0, learning_rate=0.05, max_depth=6, min_child_weight=5; total time=   0.4s
# [CV] END gamma=0, learning_rate=0.05, max_depth=6, min_child_weight=5; total time=   0.4s
# [CV] END gamma=0, learning_rate=0.05, max_depth=6, min_child_weight=1; total time=   0.7s
# [CV] END gamma=0, learning_rate=0.05, max_depth=6, min_child_weight=5; total time=   0.5s
# [CV] END gamma=0, learning_rate=0.05, max_depth=8, min_child_weight=1; total time=   0.4s
# [CV] END gamma=0, learning_rate=0.05, max_depth=6, min_child_weight=1; total time=   0.8s
# [CV] END gamma=0, learning_rate=0.05, max_depth=8, min_child_weight=5; total time=   0.2s
# [CV] END gamma=0, learning_rate=0.05, max_depth=8, min_child_weight=5; total time=   0.3s
# [CV] END gamma=0, learning_rate=0.05, max_depth=8, min_child_weight=1; total time=   0.6s
# [CV] END gamma=0, learning_rate=0.05, max_depth=8, min_child_weight=5; total time=   0.4s
# [CV] END gamma=1, learning_rate=0.01, max_depth=4, min_child_weight=1; total time=   0.4s
# [CV] END gamma=0, learning_rate=0.05, max_depth=8, min_child_weight=5; total time=   0.5s
# [CV] END gamma=0, learning_rate=0.05, max_depth=8, min_child_weight=1; total time=   0.8s
# [CV] END gamma=0, learning_rate=0.05, max_depth=8, min_child_weight=5; total time=   0.7s
# [CV] END gamma=0, learning_rate=0.05, max_depth=8, min_child_weight=1; total time=   1.0s
# [CV] END gamma=1, learning_rate=0.01, max_depth=4, min_child_weight=5; total time=   0.3s
# [CV] END gamma=1, learning_rate=0.01, max_depth=4, min_child_weight=1; total time=   0.6s
# [CV] END gamma=1, learning_rate=0.01, max_depth=4, min_child_weight=5; total time=   0.5s
# [CV] END gamma=1, learning_rate=0.01, max_depth=4, min_child_weight=1; total time=   0.7s
# [CV] END gamma=1, learning_rate=0.01, max_depth=4, min_child_weight=1; total time=   0.7s
# [CV] END gamma=1, learning_rate=0.01, max_depth=4, min_child_weight=1; total time=   0.7s
# [CV] END gamma=1, learning_rate=0.01, max_depth=4, min_child_weight=5; total time=   0.5s
# [CV] END gamma=1, learning_rate=0.01, max_depth=6, min_child_weight=1; total time=   0.4s
# [CV] END gamma=1, learning_rate=0.01, max_depth=4, min_child_weight=5; total time=   0.6s
# [CV] END gamma=1, learning_rate=0.01, max_depth=4, min_child_weight=5; total time=   0.6s
# [CV] END gamma=1, learning_rate=0.01, max_depth=6, min_child_weight=5; total time=   0.2s
# [CV] END gamma=1, learning_rate=0.01, max_depth=6, min_child_weight=5; total time=   0.4s
# [CV] END gamma=1, learning_rate=0.01, max_depth=6, min_child_weight=1; total time=   0.7s
# [CV] END gamma=1, learning_rate=0.01, max_depth=6, min_child_weight=5; total time=   0.5s
# [CV] END gamma=1, learning_rate=0.01, max_depth=6, min_child_weight=1; total time=   0.8s
# [CV] END gamma=1, learning_rate=0.01, max_depth=8, min_child_weight=1; total time=   0.3s
# [CV] END gamma=1, learning_rate=0.01, max_depth=6, min_child_weight=5; total time=   0.6s
# [CV] END gamma=1, learning_rate=0.01, max_depth=6, min_child_weight=1; total time=   0.9s
# [CV] END gamma=1, learning_rate=0.01, max_depth=6, min_child_weight=5; total time=   0.7s
# [CV] END gamma=1, learning_rate=0.01, max_depth=6, min_child_weight=1; total time=   1.0s
# [CV] END gamma=1, learning_rate=0.01, max_depth=8, min_child_weight=5; total time=   0.2s
# [CV] END gamma=1, learning_rate=0.01, max_depth=8, min_child_weight=1; total time=   0.7s
# [CV] END gamma=1, learning_rate=0.01, max_depth=8, min_child_weight=5; total time=   0.4s
# [CV] END gamma=1, learning_rate=0.05, max_depth=4, min_child_weight=1; total time=   0.2s
# [CV] END gamma=1, learning_rate=0.01, max_depth=8, min_child_weight=5; total time=   0.5s
# [CV] END gamma=1, learning_rate=0.01, max_depth=8, min_child_weight=1; total time=   0.9s
# [CV] END gamma=1, learning_rate=0.05, max_depth=4, min_child_weight=1; total time=   0.3s
# [CV] END gamma=1, learning_rate=0.01, max_depth=8, min_child_weight=5; total time=   0.6s
# [CV] END gamma=1, learning_rate=0.05, max_depth=4, min_child_weight=1; total time=   0.3s
# [CV] END gamma=1, learning_rate=0.05, max_depth=4, min_child_weight=5; total time=   0.2s
# [CV] END gamma=1, learning_rate=0.01, max_depth=8, min_child_weight=1; total time=   1.0s
# [CV] END gamma=1, learning_rate=0.05, max_depth=4, min_child_weight=1; total time=   0.3s
# [CV] END gamma=1, learning_rate=0.01, max_depth=8, min_child_weight=5; total time=   0.7s
# [CV] END gamma=1, learning_rate=0.05, max_depth=4, min_child_weight=5; total time=   0.2s
# [CV] END gamma=1, learning_rate=0.05, max_depth=4, min_child_weight=1; total time=   0.3s
# [CV] END gamma=1, learning_rate=0.05, max_depth=4, min_child_weight=5; total time=   0.2s
# [CV] END gamma=1, learning_rate=0.05, max_depth=4, min_child_weight=5; total time=   0.3s
# [CV] END gamma=1, learning_rate=0.05, max_depth=6, min_child_weight=1; total time=   0.2s
# [CV] END gamma=1, learning_rate=0.05, max_depth=4, min_child_weight=5; total time=   0.4s
# [CV] END gamma=1, learning_rate=0.01, max_depth=8, min_child_weight=1; total time=   1.3s
# [CV] END gamma=1, learning_rate=0.05, max_depth=6, min_child_weight=5; total time=   0.2s
# [CV] END gamma=1, learning_rate=0.05, max_depth=6, min_child_weight=1; total time=   0.4s
# [CV] END gamma=1, learning_rate=0.05, max_depth=6, min_child_weight=1; total time=   0.4s
# [CV] END gamma=1, learning_rate=0.05, max_depth=6, min_child_weight=1; total time=   0.5s
# [CV] END gamma=1, learning_rate=0.05, max_depth=6, min_child_weight=5; total time=   0.3s
# [CV] END gamma=1, learning_rate=0.05, max_depth=6, min_child_weight=5; total time=   0.3s
# [CV] END gamma=1, learning_rate=0.05, max_depth=8, min_child_weight=1; total time=   0.2s
# [CV] END gamma=1, learning_rate=0.05, max_depth=6, min_child_weight=1; total time=   0.6s
# [CV] END gamma=1, learning_rate=0.05, max_depth=6, min_child_weight=5; total time=   0.6s
# [CV] END gamma=1, learning_rate=0.05, max_depth=6, min_child_weight=5; total time=   0.8s
# [CV] END gamma=1, learning_rate=0.05, max_depth=8, min_child_weight=1; total time=   0.8s
# [CV] END gamma=1, learning_rate=0.05, max_depth=8, min_child_weight=5; total time=   0.7s
# [CV] END gamma=1, learning_rate=0.05, max_depth=8, min_child_weight=1; total time=   0.9s
# [CV] END gamma=1, learning_rate=0.05, max_depth=8, min_child_weight=5; total time=   0.8s
# [CV] END gamma=1, learning_rate=0.05, max_depth=8, min_child_weight=5; total time=   0.6s
# [CV] END gamma=1, learning_rate=0.05, max_depth=8, min_child_weight=1; total time=   1.0s
# [CV] END gamma=1, learning_rate=0.05, max_depth=8, min_child_weight=1; total time=   1.0s
# [CV] END gamma=1, learning_rate=0.05, max_depth=8, min_child_weight=5; total time=   0.3s
# [CV] END gamma=1, learning_rate=0.05, max_depth=8, min_child_weight=5; total time=   0.3s
#
# Best Parameters: {'gamma': 1, 'learning_rate': 0.05, 'max_depth': 6, 'min_child_weight': 1}
#
# Classification Report (Test Data):
#                precision    recall  f1-score   support
#
#          0.0       0.90      0.76      0.82       826
#          1.0       0.53      0.76      0.63       298
#
#     accuracy                           0.76      1124
#    macro avg       0.71      0.76      0.72      1124
# weighted avg       0.80      0.76      0.77      1124
#
# Accuracy: 0.7588967971530249
# True Label Distribution: Counter({0.0: 826, 1.0: 298})
# Predicted Label Distribution: Counter({np.int64(0): 697, np.int64(1): 427})
#
# Confusion Matrix:
#  [[626 200]
#  [ 71 227]]
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# [CV] END gamma=0, learning_rate=0.01, max_depth=4, min_child_weight=5; total time=   0.3s
# [CV] END gamma=0, learning_rate=0.01, max_depth=4, min_child_weight=1; total time=   0.5s
# [CV] END gamma=0, learning_rate=0.01, max_depth=4, min_child_weight=5; total time=   0.7s
# [CV] END gamma=0, learning_rate=0.01, max_depth=4, min_child_weight=5; total time=   0.8s
# [CV] END gamma=0, learning_rate=0.01, max_depth=4, min_child_weight=1; total time=   1.0s
# [CV] END gamma=0, learning_rate=0.01, max_depth=4, min_child_weight=1; total time=   1.1s
# [CV] END gamma=0, learning_rate=0.01, max_depth=4, min_child_weight=1; total time=   1.1s
# [CV] END gamma=0, learning_rate=0.01, max_depth=4, min_child_weight=1; total time=   1.1s
# [CV] END gamma=0, learning_rate=0.01, max_depth=4, min_child_weight=5; total time=   0.9s
# [CV] END gamma=0, learning_rate=0.01, max_depth=6, min_child_weight=1; total time=   0.6s
# [CV] END gamma=0, learning_rate=0.01, max_depth=4, min_child_weight=5; total time=   1.0s
# [CV] END gamma=0, learning_rate=0.01, max_depth=6, min_child_weight=5; total time=   0.4s
# [CV] END gamma=0, learning_rate=0.01, max_depth=6, min_child_weight=5; total time=   0.7s
# [CV] END gamma=0, learning_rate=0.01, max_depth=6, min_child_weight=1; total time=   1.1s
# [CV] END gamma=0, learning_rate=0.01, max_depth=6, min_child_weight=5; total time=   0.7s
# [CV] END gamma=0, learning_rate=0.01, max_depth=6, min_child_weight=1; total time=   1.2s
# [CV] END gamma=0, learning_rate=0.01, max_depth=6, min_child_weight=5; total time=   0.8s
# [CV] END gamma=0, learning_rate=0.01, max_depth=8, min_child_weight=1; total time=   0.4s
# [CV] END gamma=0, learning_rate=0.01, max_depth=6, min_child_weight=1; total time=   1.3s
# [CV] END gamma=0, learning_rate=0.01, max_depth=6, min_child_weight=5; total time=   0.9s
# ...
# [CV] END gamma=1, learning_rate=0.01, max_depth=6, min_child_weight=5; total time=   0.9s
# [CV] END gamma=1, learning_rate=0.01, max_depth=6, min_child_weight=1; total time=   1.3s
# [CV] END gamma=1, learning_rate=0.01, max_depth=8, min_child_weight=5; total time=   0.3s
# [CV] END gamma=1, learning_rate=0.01, max_depth=6, min_child_weight=1; total time=   1.4s
# [CV] END gamma=1, learning_rate=0.01, max_depth=8, min_child_weight=1; total time=   0.9s
# [CV] END gamma=1, learning_rate=0.05, max_depth=4, min_child_weight=1; total time=   0.3s
# [CV] END gamma=1, learning_rate=0.01, max_depth=8, min_child_weight=5; total time=   0.6s
# [CV] END gamma=1, learning_rate=0.01, max_depth=8, min_child_weight=5; total time=   0.7s
# [CV] END gamma=1, learning_rate=0.05, max_depth=4, min_child_weight=1; total time=   0.3s
# [CV] END gamma=1, learning_rate=0.01, max_depth=8, min_child_weight=1; total time=   1.3s
# [CV] END gamma=1, learning_rate=0.05, max_depth=4, min_child_weight=1; total time=   0.4s
# [CV] END gamma=1, learning_rate=0.01, max_depth=8, min_child_weight=5; total time=   0.9s
# [CV] END gamma=1, learning_rate=0.01, max_depth=8, min_child_weight=5; total time=   1.0s
# [CV] END gamma=1, learning_rate=0.05, max_depth=4, min_child_weight=5; total time=   0.2s
# [CV] END gamma=1, learning_rate=0.05, max_depth=4, min_child_weight=1; total time=   0.5s
# [CV] END gamma=1, learning_rate=0.01, max_depth=8, min_child_weight=1; total time=   1.5s
# [CV] END gamma=1, learning_rate=0.05, max_depth=4, min_child_weight=5; total time=   0.3s
# [CV] END gamma=1, learning_rate=0.05, max_depth=4, min_child_weight=5; total time=   0.4s
# [CV] END gamma=1, learning_rate=0.05, max_depth=4, min_child_weight=1; total time=   0.5s
# [CV] END gamma=1, learning_rate=0.05, max_depth=6, min_child_weight=1; total time=   0.3s
# [CV] END gamma=1, learning_rate=0.01, max_depth=8, min_child_weight=1; total time=   1.8s
# [CV] END gamma=1, learning_rate=0.05, max_depth=4, min_child_weight=5; total time=   0.5s
# [CV] END gamma=1, learning_rate=0.05, max_depth=4, min_child_weight=5; total time=   0.6s
# [CV] END gamma=1, learning_rate=0.05, max_depth=6, min_child_weight=1; total time=   0.5s
# [CV] END gamma=1, learning_rate=0.05, max_depth=6, min_child_weight=5; total time=   0.3s
# [CV] END gamma=1, learning_rate=0.05, max_depth=6, min_child_weight=1; total time=   0.7s
# [CV] END gamma=1, learning_rate=0.05, max_depth=6, min_child_weight=5; total time=   0.4s
# [CV] END gamma=1, learning_rate=0.05, max_depth=6, min_child_weight=1; total time=   0.7s
# [CV] END gamma=1, learning_rate=0.05, max_depth=6, min_child_weight=5; total time=   0.4s
# [CV] END gamma=1, learning_rate=0.05, max_depth=6, min_child_weight=1; total time=   0.7s
# [CV] END gamma=1, learning_rate=0.05, max_depth=8, min_child_weight=1; total time=   0.3s
# [CV] END gamma=1, learning_rate=0.05, max_depth=6, min_child_weight=5; total time=   0.5s
# [CV] END gamma=1, learning_rate=0.05, max_depth=6, min_child_weight=5; total time=   0.5s
# [CV] END gamma=1, learning_rate=0.05, max_depth=8, min_child_weight=1; total time=   0.5s
# [CV] END gamma=1, learning_rate=0.05, max_depth=8, min_child_weight=5; total time=   0.3s
# [CV] END gamma=1, learning_rate=0.05, max_depth=8, min_child_weight=5; total time=   0.4s
# [CV] END gamma=1, learning_rate=0.05, max_depth=8, min_child_weight=1; total time=   0.6s
# [CV] END gamma=1, learning_rate=0.05, max_depth=8, min_child_weight=1; total time=   0.6s
# [CV] END gamma=1, learning_rate=0.05, max_depth=8, min_child_weight=5; total time=   0.4s
# [CV] END gamma=1, learning_rate=0.05, max_depth=8, min_child_weight=1; total time=   0.6s
# [CV] END gamma=1, learning_rate=0.05, max_depth=8, min_child_weight=5; total time=   0.4s
# [CV] END gamma=1, learning_rate=0.05, max_depth=8, min_child_weight=5; total time=   0.4s
#
# Best Parameters: {'gamma': 0, 'learning_rate': 0.05, 'max_depth': 6, 'min_child_weight': 1}
#
# Classification Report (Test Data):
#                precision    recall  f1-score   support
#
#          0.0       0.87      0.81      0.84       828
#          1.0       0.56      0.67      0.61       296
#
#     accuracy                           0.77      1124
#    macro avg       0.72      0.74      0.73      1124
# weighted avg       0.79      0.77      0.78      1124
#
# Accuracy: 0.7749110320284698
# True Label Distribution: Counter({0.0: 828, 1.0: 296})
# Predicted Label Distribution: Counter({np.int64(0): 771, np.int64(1): 353})
#
# Confusion Matrix:
#  [[673 155]
#  [ 98 198]]
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# [CV] END gamma=0, learning_rate=0.01, max_depth=4, min_child_weight=5; total time=   0.3s
# [CV] END gamma=0, learning_rate=0.01, max_depth=4, min_child_weight=1; total time=   0.8s
# [CV] END gamma=0, learning_rate=0.01, max_depth=4, min_child_weight=5; total time=   0.9s
# [CV] END gamma=0, learning_rate=0.01, max_depth=4, min_child_weight=5; total time=   1.1s
# [CV] END gamma=0, learning_rate=0.01, max_depth=4, min_child_weight=1; total time=   1.5s
# [CV] END gamma=0, learning_rate=0.01, max_depth=4, min_child_weight=1; total time=   1.7s
# [CV] END gamma=0, learning_rate=0.01, max_depth=4, min_child_weight=1; total time=   2.0s
# [CV] END gamma=0, learning_rate=0.01, max_depth=4, min_child_weight=1; total time=   2.1s
# [CV] END gamma=0, learning_rate=0.01, max_depth=4, min_child_weight=5; total time=   1.9s
# [CV] END gamma=0, learning_rate=0.01, max_depth=6, min_child_weight=1; total time=   1.5s
# [CV] END gamma=0, learning_rate=0.01, max_depth=4, min_child_weight=5; total time=   1.8s
# [CV] END gamma=0, learning_rate=0.01, max_depth=6, min_child_weight=5; total time=   0.5s
# [CV] END gamma=0, learning_rate=0.01, max_depth=6, min_child_weight=5; total time=   0.8s
# [CV] END gamma=0, learning_rate=0.01, max_depth=6, min_child_weight=1; total time=   2.2s
# [CV] END gamma=0, learning_rate=0.01, max_depth=6, min_child_weight=5; total time=   1.2s
# [CV] END gamma=0, learning_rate=0.01, max_depth=6, min_child_weight=1; total time=   2.3s
# [CV] END gamma=0, learning_rate=0.01, max_depth=8, min_child_weight=1; total time=   0.9s
# [CV] END gamma=0, learning_rate=0.01, max_depth=6, min_child_weight=5; total time=   1.4s
# [CV] END gamma=0, learning_rate=0.01, max_depth=6, min_child_weight=1; total time=   2.4s
# [CV] END gamma=0, learning_rate=0.01, max_depth=6, min_child_weight=5; total time=   1.6s
# [CV] END gamma=0, learning_rate=0.01, max_depth=6, min_child_weight=1; total time=   2.6s
# [CV] END gamma=0, learning_rate=0.01, max_depth=8, min_child_weight=5; total time=   0.6s
# [CV] END gamma=0, learning_rate=0.01, max_depth=8, min_child_weight=5; total time=   1.0s
# [CV] END gamma=0, learning_rate=0.01, max_depth=8, min_child_weight=1; total time=   1.8s
# [CV] END gamma=0, learning_rate=0.01, max_depth=8, min_child_weight=5; total time=   1.5s
# [CV] END gamma=0, learning_rate=0.05, max_depth=4, min_child_weight=1; total time=   0.9s
# [CV] END gamma=0, learning_rate=0.01, max_depth=8, min_child_weight=1; total time=   2.7s
# [CV] END gamma=0, learning_rate=0.05, max_depth=4, min_child_weight=1; total time=   1.3s
# [CV] END gamma=0, learning_rate=0.01, max_depth=8, min_child_weight=5; total time=   2.0s
# [CV] END gamma=0, learning_rate=0.01, max_depth=8, min_child_weight=5; total time=   2.2s
# [CV] END gamma=0, learning_rate=0.05, max_depth=4, min_child_weight=5; total time=   0.4s
# [CV] END gamma=0, learning_rate=0.01, max_depth=8, min_child_weight=1; total time=   3.2s
# [CV] END gamma=0, learning_rate=0.05, max_depth=4, min_child_weight=1; total time=   1.4s
# [CV] END gamma=0, learning_rate=0.05, max_depth=4, min_child_weight=5; total time=   0.7s
# [CV] END gamma=0, learning_rate=0.05, max_depth=4, min_child_weight=1; total time=   1.5s
# [CV] END gamma=0, learning_rate=0.05, max_depth=4, min_child_weight=5; total time=   0.9s
# [CV] END gamma=0, learning_rate=0.01, max_depth=8, min_child_weight=1; total time=   3.7s
# [CV] END gamma=0, learning_rate=0.05, max_depth=6, min_child_weight=1; total time=   0.7s
# [CV] END gamma=0, learning_rate=0.05, max_depth=4, min_child_weight=1; total time=   1.6s
# [CV] END gamma=0, learning_rate=0.05, max_depth=4, min_child_weight=5; total time=   1.1s
# [CV] END gamma=0, learning_rate=0.05, max_depth=4, min_child_weight=5; total time=   1.2s
# [CV] END gamma=0, learning_rate=0.05, max_depth=6, min_child_weight=5; total time=   0.4s
# [CV] END gamma=0, learning_rate=0.05, max_depth=6, min_child_weight=1; total time=   1.1s
# [CV] END gamma=0, learning_rate=0.05, max_depth=6, min_child_weight=5; total time=   0.8s
# [CV] END gamma=0, learning_rate=0.05, max_depth=6, min_child_weight=1; total time=   1.6s
# [CV] END gamma=0, learning_rate=0.05, max_depth=6, min_child_weight=5; total time=   1.0s
# [CV] END gamma=0, learning_rate=0.05, max_depth=8, min_child_weight=1; total time=   0.7s
# [CV] END gamma=0, learning_rate=0.05, max_depth=6, min_child_weight=1; total time=   1.8s
# [CV] END gamma=0, learning_rate=0.05, max_depth=6, min_child_weight=5; total time=   1.3s
# [CV] END gamma=0, learning_rate=0.05, max_depth=6, min_child_weight=5; total time=   1.5s
# [CV] END gamma=0, learning_rate=0.05, max_depth=8, min_child_weight=1; total time=   1.1s
# [CV] END gamma=0, learning_rate=0.05, max_depth=6, min_child_weight=1; total time=   2.2s
# [CV] END gamma=0, learning_rate=0.05, max_depth=8, min_child_weight=5; total time=   0.5s
# [CV] END gamma=0, learning_rate=0.05, max_depth=8, min_child_weight=5; total time=   0.7s
# [CV] END gamma=0, learning_rate=0.05, max_depth=8, min_child_weight=1; total time=   1.5s
# [CV] END gamma=0, learning_rate=0.05, max_depth=8, min_child_weight=5; total time=   1.0s
# [CV] END gamma=0, learning_rate=0.05, max_depth=8, min_child_weight=1; total time=   1.8s
# [CV] END gamma=0, learning_rate=0.05, max_depth=8, min_child_weight=5; total time=   1.2s
# [CV] END gamma=1, learning_rate=0.01, max_depth=4, min_child_weight=1; total time=   1.0s
# [CV] END gamma=0, learning_rate=0.05, max_depth=8, min_child_weight=1; total time=   2.3s
# [CV] END gamma=0, learning_rate=0.05, max_depth=8, min_child_weight=5; total time=   1.5s
# [CV] END gamma=1, learning_rate=0.01, max_depth=4, min_child_weight=5; total time=   0.8s
# [CV] END gamma=1, learning_rate=0.01, max_depth=4, min_child_weight=1; total time=   1.8s
# [CV] END gamma=1, learning_rate=0.01, max_depth=4, min_child_weight=5; total time=   1.2s
# [CV] END gamma=1, learning_rate=0.01, max_depth=4, min_child_weight=1; total time=   1.8s
# [CV] END gamma=1, learning_rate=0.01, max_depth=4, min_child_weight=1; total time=   1.9s
# [CV] END gamma=1, learning_rate=0.01, max_depth=4, min_child_weight=5; total time=   1.3s
# [CV] END gamma=1, learning_rate=0.01, max_depth=4, min_child_weight=1; total time=   2.0s
# [CV] END gamma=1, learning_rate=0.01, max_depth=4, min_child_weight=5; total time=   1.4s
# [CV] END gamma=1, learning_rate=0.01, max_depth=6, min_child_weight=1; total time=   0.9s
# [CV] END gamma=1, learning_rate=0.01, max_depth=4, min_child_weight=5; total time=   1.5s
# [CV] END gamma=1, learning_rate=0.01, max_depth=6, min_child_weight=5; total time=   0.5s
# [CV] END gamma=1, learning_rate=0.01, max_depth=6, min_child_weight=5; total time=   1.1s
# [CV] END gamma=1, learning_rate=0.01, max_depth=6, min_child_weight=1; total time=   1.9s
# [CV] END gamma=1, learning_rate=0.01, max_depth=6, min_child_weight=5; total time=   1.6s
# [CV] END gamma=1, learning_rate=0.01, max_depth=6, min_child_weight=1; total time=   2.5s
# [CV] END gamma=1, learning_rate=0.01, max_depth=6, min_child_weight=5; total time=   2.0s
# [CV] END gamma=1, learning_rate=0.01, max_depth=8, min_child_weight=1; total time=   1.2s
# [CV] END gamma=1, learning_rate=0.01, max_depth=6, min_child_weight=1; total time=   2.8s
# [CV] END gamma=1, learning_rate=0.01, max_depth=6, min_child_weight=5; total time=   2.2s
# [CV] END gamma=1, learning_rate=0.01, max_depth=6, min_child_weight=1; total time=   3.0s
# [CV] END gamma=1, learning_rate=0.01, max_depth=8, min_child_weight=5; total time=   0.5s
# [CV] END gamma=1, learning_rate=0.01, max_depth=8, min_child_weight=1; total time=   1.9s
# [CV] END gamma=1, learning_rate=0.01, max_depth=8, min_child_weight=5; total time=   0.9s
# [CV] END gamma=1, learning_rate=0.05, max_depth=4, min_child_weight=1; total time=   0.4s
# [CV] END gamma=1, learning_rate=0.01, max_depth=8, min_child_weight=5; total time=   1.2s
# [CV] END gamma=1, learning_rate=0.01, max_depth=8, min_child_weight=1; total time=   2.2s
# [CV] END gamma=1, learning_rate=0.05, max_depth=4, min_child_weight=1; total time=   0.6s
# [CV] END gamma=1, learning_rate=0.01, max_depth=8, min_child_weight=5; total time=   1.7s
# [CV] END gamma=1, learning_rate=0.05, max_depth=4, min_child_weight=1; total time=   0.9s
# [CV] END gamma=1, learning_rate=0.05, max_depth=4, min_child_weight=5; total time=   0.6s
# [CV] END gamma=1, learning_rate=0.01, max_depth=8, min_child_weight=1; total time=   2.8s
# [CV] END gamma=1, learning_rate=0.01, max_depth=8, min_child_weight=5; total time=   1.9s
# [CV] END gamma=1, learning_rate=0.05, max_depth=4, min_child_weight=1; total time=   1.0s
# [CV] END gamma=1, learning_rate=0.05, max_depth=4, min_child_weight=1; total time=   1.0s
# [CV] END gamma=1, learning_rate=0.05, max_depth=4, min_child_weight=5; total time=   0.6s
# [CV] END gamma=1, learning_rate=0.05, max_depth=4, min_child_weight=5; total time=   0.6s
# [CV] END gamma=1, learning_rate=0.05, max_depth=6, min_child_weight=1; total time=   0.5s
# [CV] END gamma=1, learning_rate=0.01, max_depth=8, min_child_weight=1; total time=   3.1s
# [CV] END gamma=1, learning_rate=0.05, max_depth=4, min_child_weight=5; total time=   0.7s
# [CV] END gamma=1, learning_rate=0.05, max_depth=4, min_child_weight=5; total time=   0.7s
# [CV] END gamma=1, learning_rate=0.05, max_depth=6, min_child_weight=1; total time=   0.7s
# [CV] END gamma=1, learning_rate=0.05, max_depth=6, min_child_weight=5; total time=   0.4s
# [CV] END gamma=1, learning_rate=0.05, max_depth=6, min_child_weight=1; total time=   0.8s
# [CV] END gamma=1, learning_rate=0.05, max_depth=6, min_child_weight=1; total time=   0.9s
# [CV] END gamma=1, learning_rate=0.05, max_depth=6, min_child_weight=5; total time=   0.6s
# [CV] END gamma=1, learning_rate=0.05, max_depth=6, min_child_weight=5; total time=   0.7s
# [CV] END gamma=1, learning_rate=0.05, max_depth=6, min_child_weight=1; total time=   1.1s
# [CV] END gamma=1, learning_rate=0.05, max_depth=8, min_child_weight=1; total time=   0.6s
# [CV] END gamma=1, learning_rate=0.05, max_depth=6, min_child_weight=5; total time=   0.8s
# [CV] END gamma=1, learning_rate=0.05, max_depth=6, min_child_weight=5; total time=   0.9s
# [CV] END gamma=1, learning_rate=0.05, max_depth=8, min_child_weight=5; total time=   0.4s
# [CV] END gamma=1, learning_rate=0.05, max_depth=8, min_child_weight=1; total time=   0.8s
# [CV] END gamma=1, learning_rate=0.05, max_depth=8, min_child_weight=1; total time=   1.0s
# [CV] END gamma=1, learning_rate=0.05, max_depth=8, min_child_weight=5; total time=   0.6s
# [CV] END gamma=1, learning_rate=0.05, max_depth=8, min_child_weight=5; total time=   0.7s
# [CV] END gamma=1, learning_rate=0.05, max_depth=8, min_child_weight=1; total time=   1.0s
# [CV] END gamma=1, learning_rate=0.05, max_depth=8, min_child_weight=1; total time=   1.1s
# [CV] END gamma=1, learning_rate=0.05, max_depth=8, min_child_weight=5; total time=   0.7s
# [CV] END gamma=1, learning_rate=0.05, max_depth=8, min_child_weight=5; total time=   0.6s
#
# Best Parameters: {'gamma': 1, 'learning_rate': 0.01, 'max_depth': 6, 'min_child_weight': 1}
#
# Classification Report (Test Data):
#                precision    recall  f1-score   support
#
#          0.0       0.88      0.77      0.82       830
#          1.0       0.52      0.70      0.60       294
#
#     accuracy                           0.75      1124
#    macro avg       0.70      0.74      0.71      1124
# weighted avg       0.79      0.75      0.76      1124
#
# Accuracy: 0.75355871886121
# True Label Distribution: Counter({0.0: 830, 1.0: 294})
# Predicted Label Distribution: Counter({np.int64(0): 729, np.int64(1): 395})
#
# Confusion Matrix:
#  [[641 189]
#  [ 88 206]]

# %%
def simulate_pair(
    pair_df, 
    initial_cash_per_pair = 100.0, 
    holding_period = 5, 
    entry_threshold = 1.8, 
    use_compounding = True
):
    df = pair_df.sort_index().copy()
    pair_name = df["pair"].iloc[0]
    cash = float(initial_cash_per_pair)

    equity = pd.Series(index = df.index, dtype = float)
    equity.iloc[0] = initial_cash_per_pair
    equity.iloc[:] = np.nan
    equity.iloc[0] = initial_cash_per_pair

    trades = []
    i = 0
    n = len(df)

    while i < n - holding_period:
        row = df.iloc[i]
        prob = row["prob"]

        if (prob >= 0.5) and (abs(row["zscore"]) >= entry_threshold):
            entry_idx = i
            exit_idx = i + holding_period
            entry_date = df.index[entry_idx]
            exit_date = df.index[exit_idx]

            price1_in, price2_in = row["etf1"], row["etf2"]
            price1_out, price2_out = df.iloc[exit_idx]["etf1"], df.iloc[exit_idx]["etf2"]

            notional = cash if use_compounding else initial_cash_per_pair
            long_dollars, short_dollars = notional / 2.0, notional / 2.0

            if row["zscore"] > 0:
                shares_short1 = short_dollars / price1_in
                shares_long2  = long_dollars / price2_in
                pnl = (shares_long2 * (price2_out - price2_in)) + (shares_short1 * (price1_in - price1_out))
                direction = "Short ETF1 / Long ETF2"
            else:
                shares_long1  = long_dollars / price1_in
                shares_short2 = short_dollars / price2_in
                pnl = (shares_long1 * (price1_out - price1_in)) + (shares_short2 * (price2_in - price2_out))
                direction = "Long ETF1 / Short ETF2"

            cash += pnl
            equity.loc[entry_date:exit_date] = cash

            trades.append({
                "pair": pair_name,
                "entry_date": entry_date,
                "exit_date": exit_date,
                "direction": direction,
                "pnl": float(pnl),
                "notional": float(notional)
            })

            i = exit_idx + 1
        else:
            equity.iloc[i] = cash
            i += 1

    equity.ffill(inplace=True)
    return equity, trades


pair_results = []
initial_cash_per_pair = 100.0

for etf1, etf2 in etf_pairs:
    pair_name = f"{etf1}_{etf2}"

    test_pair = process_pair(etf1, etf2, test_prices).copy()

    model = pair_models[pair_name]

    X_test_pair = test_pair[feature_cols]
    test_pair['prediction'] = model.predict(X_test_pair)
    test_pair['prob'] = model.predict_proba(X_test_pair)[:, 1]

    equity, trades = simulate_pair(test_pair)

    pair_results.append({
        "pair": pair_name,
        "equity": equity,
        "trades": trades,
        "final_value": equity.iloc[-1],
        "total_return": (equity.iloc[-1] / equity.iloc[0] - 1) * 100,
        "n_trades": len(trades)
    })

sns.set_theme(style = "whitegrid", context = "notebook")

plt.figure(figsize = (12, 6))
combined_equity = 0

for result in pair_results:
    sns.lineplot(
        x = result["equity"].index,
        y = result["equity"].values,
        label = result["pair"],
        linewidth = 2,
        alpha = 0.9
    )
    if isinstance(combined_equity, int):
        combined_equity = result["equity"]
    else:
        combined_equity = combined_equity.add(result["equity"], fill_value=0)

plt.title("XGBoost Equity Curve by Pair", fontsize = 15, weight="bold")
plt.xlabel("Date", fontsize = 12)
plt.ylabel("Portfolio Value ($)", fontsize = 12)
plt.legend(title = "Pair", frameon=True)
plt.grid(True)
plt.tight_layout()
plt.show()

plt.figure(figsize = (12, 6))
sns.lineplot(
    x = combined_equity.index,
    y = combined_equity.values,
    label = "Total",
    color = "black",
    linewidth = 2,
    alpha = 0.9
)
plt.title("Total Portfolio Equity", fontsize = 15, weight="bold")
plt.xlabel("Date", fontsize = 12)
plt.ylabel("Portfolio Value ($)", fontsize = 12)
plt.legend(frameon = True)
plt.grid(True)
plt.tight_layout()
plt.show()

print("Summary")
for result in pair_results:
    print(f"{result['pair']}: Final Value = ${result['final_value']:.2f}, "
          f"Total Return = {result['total_return']:.2f}%, Trades = {result['n_trades']}")

initial_total_value = combined_equity.iloc[0]
final_total_value = combined_equity.iloc[-1]
total_return_pct = (final_total_value - initial_total_value) / initial_total_value * 100

print("\nTotal Portfolio Performance")
print(f"Initial Portfolio Value: ${initial_total_value:,.2f}")
print(f"Final Portfolio Value:   ${final_total_value:,.2f}")
print(f"Total Return:            {total_return_pct:.2f}%")

combined_equity.to_csv("equity_curves/xgboost_equity.csv", header = ["Portfolio Value"])
# Out:
# Summary
# VO_IWB: Final Value = $103.55, Total Return = 3.55%, Trades = 34
# VO_SPY: Final Value = $103.01, Total Return = 3.01%, Trades = 33
# VO_SCHX: Final Value = $100.66, Total Return = 0.66%, Trades = 36
# VO_SPLG: Final Value = $102.42, Total Return = 2.42%, Trades = 33
# VO_IVV: Final Value = $102.92, Total Return = 2.92%, Trades = 27
# VO_VOO: Final Value = $103.17, Total Return = 3.17%, Trades = 29
# DVY_IWR: Final Value = $102.02, Total Return = 2.02%, Trades = 36
# SCHV_SPHQ: Final Value = $101.28, Total Return = 1.28%, Trades = 29
# IWR_DIA: Final Value = $106.45, Total Return = 6.23%, Trades = 44
# DVY_OEF: Final Value = $107.76, Total Return = 7.76%, Trades = 39
# VTV_SPHQ: Final Value = $105.71, Total Return = 5.71%, Trades = 29
# RSP_DIA: Final Value = $100.90, Total Return = 0.87%, Trades = 32
# VO_DIA: Final Value = $103.51, Total Return = 2.94%, Trades = 32
# DVY_FVD: Final Value = $102.10, Total Return = 2.10%, Trades = 36
# DVY_VYM: Final Value = $101.49, Total Return = 1.49%, Trades = 27
#
# Total Portfolio Performance
# Initial Portfolio Value: $1,500.80
# Final Portfolio Value:   $1,546.96
# Total Return:            3.08%

# %%
def compute_sharpe_ratio(equity_series):
    daily_returns = equity_series.pct_change().dropna()
    mean_return = daily_returns.mean()
    std_return = daily_returns.std()
    sharpe = (mean_return / std_return) * np.sqrt(252) if std_return > 0 else np.nan
    return sharpe

print("\nSharpe Ratios")
for result in pair_results:
    sharpe = compute_sharpe_ratio(result["equity"])
    result["sharpe"] = sharpe
    print(f"{result['pair']}: Sharpe Ratio = {sharpe:.2f}")

portfolio_sharpe = compute_sharpe_ratio(combined_equity)
print(f"\nTotal Portfolio Sharpe Ratio: {portfolio_sharpe:.2f}")
# Out:
# Sharpe Ratios
# VO_IWB: Sharpe Ratio = 0.69
# VO_SPY: Sharpe Ratio = 0.58
# VO_SCHX: Sharpe Ratio = 0.13
# VO_SPLG: Sharpe Ratio = 0.40
# VO_IVV: Sharpe Ratio = 0.53
# VO_VOO: Sharpe Ratio = 0.58
# DVY_IWR: Sharpe Ratio = 0.24
# SCHV_SPHQ: Sharpe Ratio = 0.20
# IWR_DIA: Sharpe Ratio = 0.87
# DVY_OEF: Sharpe Ratio = 0.70
# VTV_SPHQ: Sharpe Ratio = 0.89
# RSP_DIA: Sharpe Ratio = 0.19
# VO_DIA: Sharpe Ratio = 0.47
# DVY_FVD: Sharpe Ratio = 0.35
# DVY_VYM: Sharpe Ratio = 0.41
#
# Total Portfolio Sharpe Ratio: 1.35

# %%
def compute_max_drawdown(equity_curve):
    cumulative_max = equity_curve.cummax()
    drawdown = (equity_curve - cumulative_max) / cumulative_max
    max_drawdown = drawdown.min()
    print(f"Max Drawdown: {max_drawdown:.2%}")
    return max_drawdown

for result in pair_results:
    print({result["pair"]})
    _ = compute_max_drawdown(result['equity'])
    
print("Total Max Drawdown")
_ = compute_max_drawdown(combined_equity)
# Out:
# {'VO_IWB'}
# Max Drawdown: -0.84%
# {'VO_SPY'}
# Max Drawdown: -2.06%
# {'VO_SCHX'}
# Max Drawdown: -2.39%
# {'VO_SPLG'}
# Max Drawdown: -2.16%
# {'VO_IVV'}
# Max Drawdown: -2.26%
# {'VO_VOO'}
# Max Drawdown: -1.92%
# {'DVY_IWR'}
# Max Drawdown: -2.69%
# {'SCHV_SPHQ'}
# Max Drawdown: -1.94%
# {'IWR_DIA'}
# Max Drawdown: -2.08%
# {'DVY_OEF'}
# Max Drawdown: -2.11%
# {'VTV_SPHQ'}
# Max Drawdown: -1.28%
# {'RSP_DIA'}
# Max Drawdown: -1.19%
# {'VO_DIA'}
# Max Drawdown: -2.22%
# {'DVY_FVD'}
# Max Drawdown: -3.49%
# {'DVY_VYM'}
# Max Drawdown: -1.28%
# Total Max Drawdown
# Max Drawdown: -0.82%
